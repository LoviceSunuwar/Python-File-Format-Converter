# %%
# %pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp39-cp39-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl.metadata (61 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Using cached pandas-2.2.2-cp39-cp39-win_amd64.whl (11.6 MB)
# Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install dask\[complete\]
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "\\Mac\Home\Documents\Data Engineering\Python-File-Format-Converter\.venv\lib\site-packages\pip\_vendor\packaging\requirements.py", line 102, in __init__
#     req = REQUIREMENT.parseString(requirement_string)
#   File "\\Mac\Home\Documents\Data Engineering\Python-File-Format-Converter\.venv\lib\site-packages\pip\_vendor\pyparsing\util.py", line 256, in _inner
#     return fn(self, *args, **kwargs)
#   File "\\Mac\Home\Documents\Data Engineering\Python-File-Format-Converter\.venv\lib\site-packages\pip\_vendor\pyparsing\core.py", line 1190, in parse_string
#     raise exc.with_traceback(None)
# pip._vendor.pyparsing.exceptions.ParseException: Expected string_end, found '['  (at char 11), (line:1, col:12)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
# %pip install pyspark
# Out:
# ...
#      ---------------------------------------- 0.0/317.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.0 MB 1.9 MB/s eta 0:02:46
#      ---------------------------------------- 0.1/317.0 MB 1.1 MB/s eta 0:05:02
#      ---------------------------------------- 0.2/317.0 MB 1.3 MB/s eta 0:04:04
#      ---------------------------------------- 0.2/317.0 MB 1.3 MB/s eta 0:04:03
#      ---------------------------------------- 0.3/317.0 MB 1.4 MB/s eta 0:03:53
#      ---------------------------------------- 0.4/317.0 MB 1.5 MB/s eta 0:03:28
#      ---------------------------------------- 0.5/317.0 MB 1.6 MB/s eta 0:03:23
#      ---------------------------------------- 0.5/317.0 MB 1.7 MB/s eta 0:03:10
#      ---------------------------------------- 0.6/317.0 MB 1.7 MB/s eta 0:03:09
#      ---------------------------------------- 0.7/317.0 MB 1.8 MB/s eta 0:02:58
#      ---------------------------------------- 0.8/317.0 MB 1.7 MB/s eta 0:03:12
# ...
